# %%
import pandas
df = pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Continent"] = df.shape[0]*["Asia"]

# %%
df["City"] = df.shape[0]*["Delhi"]

# %%
df["State"] = df.shape[0] * ["UT"]

# %%
df["Country"] = df.shape[0] * ["INDIA"]

# %%
df_t=df.T

# %%
df_t
# Out:
#                       0               1            2             3  \
# ID                    1               2            3             4
# Address    3666 21st St  735 Dolores St  332 Hill St  3995 23rd St
# City              Delhi           Delhi        Delhi         Delhi
# State                UT              UT           UT            UT
# Country           INDIA           INDIA        INDIA         INDIA
# Name            Madeira     Bready Shop  Super River    Ben's Shop
# Employees             8              15           25            10
# Continent          Asia            Asia         Asia          Asia
#
#                          4                5
# ID                       5                6
# Address    1056 Sanchez St  551 Alvarado St
# City                 Delhi            Delhi
# State                   UT               UT
# Country              INDIA            INDIA
# Name               Sanchez       Richvalley
# Employees               12               20
# ...

# %%
df["6"] = ["7","334 Bekar St", "Delhi", "UT", "INDIA", "Donald", "45", "Asia"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-85c9478d2ae2> in <module>()
# ----> 1 df["6"] = ["7","334 Bekar St", "Delhi", "UT", "INDIA", "Donald", "45", "Asia"]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _sanitize_column(self, key, value, broadcast)
#    3628
# ...
